# %%
import matplotlib    
import matplotlib.font_manager

[f.name for f in matplotlib.font_manager.fontManager.ttflist if 'Nanum' in f.name]
 # ['NanumBarunGothic',
 # 'NanumMyeongjo',
 # 'NanumMyeongjo',
 # 'NanumGothic',
 # 'NanumBarunGothic',
 # 'NanumGothic']
# Out:
# ['NanumGothic',
#  'NanumMyeongjo',
#  'NanumMyeongjo',
#  'NanumBarunGothic',
#  'NanumSquare',
#  'NanumSquareRound',
#  'NanumBarunGothic',
#  'NanumGothic',
#  'NanumSquareRound',
#  'NanumSquare']

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# 유니코드 깨짐현상 해결
mpl.rcParams['axes.unicode_minus'] = False

# 나눔고딕 폰트 적용
plt.rcParams["font.family"] = 'NanumGothic'

# %%
import os
import pandas as pd

os.getcwd()
# Out:
# '/home/piai/바탕화면/01 실습파일/1 Big Data 분석 기초'

# %%
os.chdir('/home/piai/바탕화면/01 실습파일/1 Big Data 분석 기초')

# %%
df = pd.read_csv("FITNESS_정제.csv", encoding = 'euc-kr')
df.head(5)
# Out:
#      NAME GENDER  AGE AGEGROUP  WEIGHT     OXY   RUNTIME  RUNPULSE  RSTPULSE  \
# 0   Donna     여성   42      40대   68.15  59.571  8.17 SEC       166        40
# 1  Gracie    NaN   38      30대   81.87  60.055  8.63 SEC       170        48
# 2  Luanne     여성   43      40대   85.84  54.297  8.65 SEC       156        45
# 3    Mimi     여성   50      50대   70.87  54.625  8.92 SEC       146        48
# 4   Chris     남성   49      40대     NaN  49.156  8.95 SEC       180        44
#
#    MAXPULSE       BIRTH
# 0       172  1976-04-05
# 1       186  1986-09-06
# 2       168  1978-04-07
# 3       155  1966-08-08
# 4       185  1977-02-09

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

import matplotlib
import matplotlib.pyplot as plt

import seaborn as sns
# %matplotlib inline

from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

# %%
df_fitness = pd.read_csv("FITNESS.csv", encoding = 'euc-kr')
df_fitness.head()
# Out:
#      NAME GENDER  AGE AGEGROUP  WEIGHT     OXY  RUNTIME  RUNPULSE  RSTPULSE  \
# 0   Donna     여성   42      40대   68.15  59.571     8.17       166        40
# 1  Gracie     여성   38      30대   81.87  60.055     8.63       170        48
# 2  Luanne     여성   43      40대   85.84  54.297     8.65       156        45
# 3    Mimi     여성   50      50대   70.87  54.625     8.92       146        48
# 4   Chris     남성   49      40대   81.42  49.156     8.95       180        44
#
#    MAXPULSE
# 0       172
# 1       186
# 2       168
# 3       155
# 4       185

# %%
df_currency = pd.read_csv("환율.csv", parse_dates = ["APPL_DATE"])
df_currency.head()
# Out:
#   CURRENCY  APPL_DATE  STD_RATE  USD_CONV_DATE
# 0      CNY 2016-01-01    181.48         0.1541
# 1      JPY 2016-01-01    976.99         0.8294
# 2      USD 2016-01-01   1178.00         1.0000
# 3      CNY 2016-01-02    181.48         0.1541
# 4      JPY 2016-01-02    976.99         0.8294

# %% [markdown]
# # Bar Chart 그리기

# %%
# 성별 Bar Chart
sns.countplot(x='GENDER',  data=df_fitness)
# Out:
# <Axes: xlabel='GENDER', ylabel='count'>

# %%
# 성별 Bar Chart
sns.countplot(x='GENDER',  data=df_fitness)
plt.show()

# %%
df_fitness['GENDER'].value_counts().plot(kind='bar',rot=0,color=['blue','red'])
# Out:
# <Axes: >

# %%
# 연령대 Bar Chart
sns.countplot(x="AGEGROUP", data=df_fitness)
# Out:
# <Axes: xlabel='AGEGROUP', ylabel='count'>

# %%
# 연령대 Bar Chart
sns.countplot(x="AGEGROUP", data=df_fitness, palette='Set3')
# Out:
# <Axes: xlabel='AGEGROUP', ylabel='count'>

# %%
# 성별+연령대 Bar Chart
sns.countplot(x="AGEGROUP", hue="GENDER", data=df_fitness)
# Out:
# <Axes: xlabel='AGEGROUP', ylabel='count'>

# %%
# 성별+연령대 Bar Chart
sns.countplot(x="AGEGROUP", hue="GENDER", data=df_fitness, palette='Set3')
# Out:
# <Axes: xlabel='AGEGROUP', ylabel='count'>

# %% [markdown]
# # Histogram 그리기

# %%
# df.hist method 이용 : OXY에 대한 히스토그램 생성 
sns.histplot(data=df_fitness, x="OXY")
# Out:
# <Axes: xlabel='OXY', ylabel='Count'>

# %%
df_fitness['OXY'].hist(grid=False, bins=7)
# Out:
# <Axes: >

# %%
# hist(figsiz) : figsize = (x축 크기, y축 크기)-그래프 영역별 중첩 처리
df_fitness.hist(figsize = (10,7))
# Out:
# array([[<Axes: title={'center': 'AGE'}>,
#         <Axes: title={'center': 'WEIGHT'}>,
#         <Axes: title={'center': 'OXY'}>],
#        [<Axes: title={'center': 'RUNTIME'}>,
#         <Axes: title={'center': 'RUNPULSE'}>,
#         <Axes: title={'center': 'RSTPULSE'}>],
#        [<Axes: title={'center': 'MAXPULSE'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
# hist(변수,label="표시 값" , alpha = 투명도(0~1 지정) )
plt.hist(df_fitness[df_fitness["GENDER"] == "남성"]["OXY"],label = "남성", alpha = 1.0)
plt.hist(df_fitness[df_fitness["GENDER"] == "여성"]["OXY"],label = "여성", alpha = 0.5)
plt.legend()

# %%
# hist(변수,label="표시 값" , alpha = 투명도(0~1 지정) )
plt.hist(df_fitness[df_fitness["GENDER"] == "남성"]["OXY"],label = "남성", alpha = 1.0)
plt.show()
plt.hist(df_fitness[df_fitness["GENDER"] == "여성"]["OXY"],label = "여성", alpha = 0.5)
plt.show()

# %%
# seabon을 이용 histogram 그리기 
sns.histplot(data=df_fitness, x="OXY")
# Out:
# <Axes: xlabel='OXY', ylabel='Count'>

# %%
# x축 구간(bin) 조정(상세 분포 확인)
sns.histplot(data=df_fitness, x="OXY", bins=10)
# Out:
# <Axes: xlabel='OXY', ylabel='Count'>

# %% [markdown]
# # Boxplot 그리기

# %%
# 연령대 혈당 산소 요구량 분포
sns.boxplot(y='OXY', x='AGEGROUP', data=df_fitness, palette='Set3')
# Out:
# <Axes: xlabel='AGEGROUP', ylabel='OXY'>

# %%
# 연령대 혈당 산소 요구량 분포
sns.boxplot(y='OXY', x='GENDER', data=df_fitness, palette='Set3')
# Out:
# <Axes: xlabel='GENDER', ylabel='OXY'>

# %%
# 성별+연령대 혈당 산소 요구량 분포
sns.boxplot(y='OXY', x= 'GENDER',hue='AGEGROUP', data=df_fitness)
# Out:
# <Axes: xlabel='GENDER', ylabel='OXY'>

# %%
# boxplot(column= 변수, by=  그룹 변수) 
df_fitness.boxplot(column="OXY", by = ["GENDER", "AGEGROUP"])
# Out:
# <Axes: title={'center': 'OXY'}, xlabel='[GENDER, AGEGROUP]'>

# %% [markdown]
# # Pie Chart 그리기

# %%
#성별 Pie Chart
# groupby(column):column기준 자료 요약.(size : group별 자료 수)
df_count = df_fitness.groupby(["GENDER"] ).size()
# pie(데이터,labels=레이블  변수 지정,autopct=비율 %로 표시(%.1f%%: 소수점 1자리 적용)
df_count.plot.pie(y = "OXY", autopct="%.1f%%")
# Out:
# <Axes: >

# %%
#성별+연령대 Pie Chart
# groupby(column):column기준 자료 요약.(size : group별 자료 수)
df_count = df_fitness.groupby(["GENDER", "AGEGROUP"] ).size()
# pie(데이터,labels=레이블  변수 지정,autopct=비율 %로 표시(%.1f%%: 소수점 1자리 적용)
df_count.plot.pie(y = "OXY", autopct="%.1f%%")
# Out:
# <Axes: >

# %%
df_fitness.groupby(["GENDER", "AGEGROUP"] ).size()
# Out:
# GENDER  AGEGROUP
# 남성      30대         4
#         40대         6
#         50대         5
# 여성      30대         2
#         40대         8
#         50대         6
# dtype: int64

# %%
df_count = df_fitness.groupby(["GENDER", "AGEGROUP"] ).size()

df_count.plot.pie(y = "OXY", autopct="%.1f%%", explode = (0, 0.05, 0, 0, 0.05, 0), startangle=90, counterclock=False)
# Out:
# <Axes: >

# %% [markdown]
# # Scatter Plot 그리기

# %%
# scatterplot( x, y, hue: 그룹 변수, style : 그룹별 marker 구분 ,  data )
sns.scatterplot(x = "RUNTIME", y = "OXY", hue = "GENDER", style= "GENDER", data = df_fitness  )
# Out:
# <Axes: xlabel='RUNTIME', ylabel='OXY'>

# %%
# 회귀선 + 플롯 그리기 (seaborn lmplot)
sns.lmplot(data=df_fitness, x = "RUNTIME", y = "OXY", hue="GENDER")

# %%
# pairplot(데이터): Scatter Plot  그래프 생성
sns.pairplot(df_fitness)

# %%
# y변수: 혈당산소 요구량, x변수: 맥박(운동), 맥박(최대), 운동시간 Scatter Matrix 생성
# pairplot(데이터, y_vars = y축 변수 , x_vars = x축 변수 ): Scatter Plot  그래프 생성
sns.pairplot(df_fitness , y_vars=["OXY"] , x_vars=["RUNPULSE","MAXPULSE","RUNTIME"] )

# %% [markdown]
# # Trend Chart 그리기

# %%
df_currency
# Out:
#     CURRENCY  APPL_DATE  STD_RATE  USD_CONV_DATE
# 0        CNY 2016-01-01    181.48         0.1541
# 1        JPY 2016-01-01    976.99         0.8294
# 2        USD 2016-01-01   1178.00         1.0000
# 3        CNY 2016-01-02    181.48         0.1541
# 4        JPY 2016-01-02    976.99         0.8294
# ..       ...        ...       ...            ...
# 268      JPY 2016-03-30   1026.90         0.8906
# 269      USD 2016-03-30   1153.00         1.0000
# 270      CNY 2016-03-31    176.96         0.1547
# 271      JPY 2016-03-31   1017.57         0.8895
# 272      USD 2016-03-31   1144.00         1.0000
#
# [273 rows x 4 columns]

# %%
# Pivot 활용하여 각국 통화별 데이터 생성
df_currency_pivot = df_currency.pivot(index = "APPL_DATE", columns="CURRENCY", values = "STD_RATE")
df_currency_pivot.head()
# Out:
# CURRENCY       CNY     JPY     USD
# APPL_DATE
# 2016-01-01  181.48  976.99  1178.0
# 2016-01-02  181.48  976.99  1178.0
# 2016-01-03  181.48  976.99  1178.0
# 2016-01-04  181.10  992.62  1184.0
# 2016-01-05  181.94  993.00  1185.0

# %%
# 중국 위안화 별도 그림(엔화, 달러와 단위 차이)
df_currency_pivot["CNY"].plot()
# Out:
# <Axes: xlabel='APPL_DATE'>

# %%
# 일본 엔화, 미국 달러
df_currency_pivot[["JPY", "USD"]].plot()
# Out:
# <Axes: xlabel='APPL_DATE'>

# %% [markdown]
# # Heatmap 그리기

# %%
# 성별과 연령대별 혈당 산소 요구량 평균 계산, groupby: (성별, 연령), agg("mean"): 혈당 산소 요구량 평균값
df_agg = df_fitness.groupby(["GENDER", "AGEGROUP"], as_index = False).agg("mean")
# pivot(성별, 연령대, 혈당 산소 요구량): x축(연령대), y축(성별), 값(혈당산소요구량의 평균)으로 pivot
df_pivot = df_agg.pivot("GENDER", "AGEGROUP", "OXY")
# heatmap(데이터, cmap: 색상)
sns.heatmap(df_pivot, cmap="Blues")
# Out:
# <Axes: xlabel='AGEGROUP', ylabel='GENDER'>

# %%
df_pivot = df_agg.pivot_table(index = "GENDER", columns = "AGEGROUP", values = "OXY", aggfunc = 'mean')
# heatmap(데이터, cmap: 색상)
sns.heatmap(df_pivot, annot = True, cmap="viridis")
# Out:
# <Axes: xlabel='AGEGROUP', ylabel='GENDER'>

# %%
df_fitness.select_dtypes('number').corr()
# Out:
#                AGE    WEIGHT       OXY   RUNTIME  RUNPULSE  RSTPULSE  MAXPULSE
# AGE       1.000000 -0.264408 -0.249929  0.133988 -0.333892 -0.183458 -0.381818
# WEIGHT   -0.264408  1.000000 -0.162753  0.143508  0.181516  0.043974  0.249381
# OXY      -0.249929 -0.162753  1.000000 -0.862195 -0.397974 -0.399356 -0.236740
# RUNTIME   0.133988  0.143508 -0.862195  1.000000  0.313648  0.450383  0.226103
# RUNPULSE -0.333892  0.181516 -0.397974  0.313648  1.000000  0.352461  0.929754
# RSTPULSE -0.183458  0.043974 -0.399356  0.450383  0.352461  1.000000  0.305124
# MAXPULSE -0.381818  0.249381 -0.236740  0.226103  0.929754  0.305124  1.000000

# %%
sns.heatmap(df_fitness.select_dtypes('number').corr(), annot=True, cmap="viridis")
# Out:
# <Axes: >

# %%
# 상관분석
df_corr = df_fitness.corr()
sns.heatmap(df_corr, annot = True, cmap="viridis")
# Out:
# <Axes: >

# %% [markdown]
# # Contour Plot 그리기

# %%
# kdeplot( x축, y축 , shade: 음영 선택 여부) 
sns.kdeplot(df_fitness, x="RUNTIME", y="OXY",shade = False)
# Out:
# <Axes: xlabel='RUNTIME', ylabel='OXY'>

# %%
# kdeplot( x축, y축 , shade: 음영 선택 여부) 
sns.kdeplot(x="RUNTIME", y="OXY", data=df_fitness, shade = True)
# Out:
# <Axes: xlabel='RUNTIME', ylabel='OXY'>

# %% [markdown]
# # Parallel Plot 그리기

# %%
# parallel_coordinates(데이터, 그룹 변수, cols = 변수, colormap= 다양한 colormap지정)
pd.plotting.parallel_coordinates(df_fitness,"GENDER", cols=["OXY", "WEIGHT", "RSTPULSE"],
                                 colormap="Accent")
# Out:
# <Axes: >

# %%
# 192 Page
df_count = df_fitness["AGEGROUP"].value_counts()                  # Pie Chart를 위한 집계 데이터
fig, axes = plt.subplots(nrows=2, ncols=2, figsize = (13, 10))    # (2, 2) 4분할, 4개의 그래프 생성
plt.tight_layout(w_pad=5, h_pad=5)                                # w_pad: 열 사이 간격, h_pad: 행 사이 간격
# Histogram
axes[0,0].hist(df_fitness["OXY"])                                 # [0,0] 위치에 Histogram 생성
axes[0,0].set_title("Histogram", fontsize = 15)                   # 제목 설정, 글자 크기 15
axes[0,0].set_xlabel("혈당 산소 요구량", fontsize = 12)           # x축 label 지정
# Pie Chart
axes[0,1].pie(df_count, labels = df_count.index.tolist(), autopct = "%.1f%%") # [0,1] 위치에 Pie Chart 생성
axes[0,1].set_title("Pie Chart", fontsize = 15) 
axes[0,1].set_xlabel("연령대", fontsize = 12)
# Trend
axes[1,0].plot("RUNTIME", "RUNPULSE", data = df_fitness, label = "맥박(운동)") # [1, 0]  x축: 운동 시간, y축: 맥박(운동)
axes[1,0].plot("RUNTIME", "OXY", data = df_fitness, label = "혈당 산소 요구량") # x축: 운동 시간, y축: 산소 요구량
axes[1,0].set_title("Trend", fontsize = 15)
axes[1,0].set_xlabel("운동 시간", fontsize = 12)
axes[1,0].legend()         # 범례 표시
# Scatter
axes[1,1].scatter("RUNPULSE", "OXY", data = df_fitness)   # [1,1] 위치에 산점도 표시, x축: 맥박(운동) , y축: 산소 요구량
axes[1,1].set_title("Scatter", fontsize = 15)
axes[1,1].set_xlabel("맥박(운동)", fontsize = 12)
axes[1,1].set_ylabel("혈당 산소 요구량", fontsize = 12)
# Out:
# Text(675.7676767676767, 0.5, '혈당 산소 요구량')
